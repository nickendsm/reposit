# %% [markdown]
# # решаем несколько задач на строки

# %% [markdown]
# # 1
# # Написать функцию search_substr(subst,st), которая принимает 2 строки на вход и определяет, имеется ли подстрока subst в строке st. В случае нахождения подстроки возвращается фраза "Есть контакт!", а иначе "Мимо!".
# # Должно быть найдено совпадение в независимости от регистра.

# %%
def search_substr (st,substr):
    # так как регистр не важен, нам нужно привести всю строку st и substr к низу
    st_new = st.lower()
    substr_new =  substr.lower()
    if substr_new in st_new:
        print('Есть контакт!')
    else: 
        print('Мимо!')
search_substr('Кошка','кош')
# здесь мы использовали метод lower
# Out:
# Есть контакт!

# %% [markdown]
# # 2
# # Требуется определить индексы первого и последнего вхождения буквы в строке.
# # Для этого нужно написать функцию first_last(letter, st), включающую 2 параметра: letter – искомый символ, st – целевая строка.
# # В случае отсутствия буквы в строке, нужно вернуть кортеж (None, None), если же она есть, то кортеж будет состоять из первого и последнего индекса этого символа.

# %%
def first_last(st,letter):
    first = st.lower().find(letter.lower())
    if (first != -1):
        last = st.lower().rfind(letter.lower())
        return first,last
    else:
        return None,None
first_last('Кошка','а')
# посмотрели на find, rfind
# Out:
# (4, 4)

# %% [markdown]
# # 3
# # На основании предоставленного отрывка текста определить 3 наиболее часто встречаемых символа в ней.
# # Пробелы нужно игнорировать (не учитывать при подсчете).
# # Для выведения результатов вычислений требуется написать функцию top3(st).
# # Итог работы функции представить в виде строки: «символ – количество раз, символ – количество раз…».

# %%
# из-за того, что строка - неизменяемый упорядоченный объект, мы можем обращаться по очереди к ее символам
def top3(st):
    # введем словарь для подсчета символов. Словарь будет состоять из ключа-символа и числа - сколько раз он встречается
    D = dict()
    for symb in st.lower():
        if (symb == ' '):
            continue
            print(2)
        if (symb in D):
            D[symb] += 1
        else:
            D[symb] = 1
    fst = max(D, key = D.get)
    cnt1 = D[fst]
    del(D[fst])
    sec = max(D, key = D.get)
    cnt2 = D[sec]
    del(D[sec])
    thd = max(D, key = D.get)
    cnt3 = D[thd]
    return fst + ' - ' + str(cnt1) + ', ',sec + ' - '+ str(cnt2) + ', ',thd+ ' - ' + str(cnt3)
top3('Коошшшаааа')
# lower для строк, get для словаря,
# Out:
# ('а - 4, ', 'ш - 3, ', 'о - 2')

# %%
# 2 способ (через collections)
import collections as cl
def top3(st):
    counter_top3 = cl.Counter(st.replace(' ', '')).most_common(3)
    return ', '.join([f'{letter} - {cnt}' for letter, cnt in counter_top3])
top3('Коошшшаааа')
# библиотека collections, Counter - подкласс Dictionary, метод most_common класса Counter
# метод строк join
# Out:
# 'а - 4, ш - 3, о - 2'

# %% [markdown]
# # 4
# # Александр решил как-то отобразить в тексте BACKSPACE (т.е. удаление последнего символа).
# # Он подумал, что символ «@» отлично для этого подходит.
# # Всем своим знакомым он дал строки такого вида (например, «гр@оо@лк@оц@ва»), чтобы посмотреть, кому удастся написать функцию cleaned_str(st), возвращающую строку в ее чистом виде.

# %%
def cleaned_str(st):
    # каждый раз когда находим @, нужно удалить @ и предыдущий символ
    # нужно придумать как выкидывать из списка символы, так как список - неизменяемый объект
    # каждый раз создавать новый объект - нерационально
    # поэтому резонней перевести строку в список
    clean_str = [] # список
    for symb in st:
        if (symb == '@'):
            clean_str.pop(-1) 
            continue
        clean_str.append(symb)
    return ''.join(clean_str)
cleaned_str('сварк@атоп')
# метод join для строк, метод pop для списка
# Out:
# 'сваркатоп'

# %%
print(cleaned_str('сварка@@@@@лоб@ну@'))
# Out:
# слон

# %%
print(cleaned_str('гр@оо@лк@оц@ва'))
# Out:
# голова

# %% [markdown]
# # 5
# # Небольшой пример использования split для строк

# %% [markdown]
# # пусть у нас имеется датасет (табличка с данными) по автомобилям
# # столбцы в этой таблице содержат разные характеристики и одна из них - марка машины
# # в файле имеются пропуски в этом столбце.
# # Нужно, исходя из столбца описания машины вычленить марку машины для дальнейшего использования

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/vehicles_dataset.csv')

# %%
df.head()
# видим, что есть столбец model, посмотрим повнимательней
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price    year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020.0
# 1   north jersey     https://newjersey.craigslist.org  16942  2016.0
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017.0
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013.0
# 4  new york city       https://newyork.craigslist.org  21800  2021.0
#
#   manufacturer                   model condition    cylinders  ...    type  \
# 0          ram  2500 crew cab big horn      good          NaN  ...  pickup
# ...

# %%
df.model.isna().sum() # имеем 129 пропусков, непорядок
# Out:
# 129

# %%
# посмотрим на тот кусок данных, где пропущена модель
df[df.model.isna()]
# Out:
#                id                                                url  \
# 67     7316913641  https://ventura.craigslist.org/cto/d/camarillo...
# 142    7316550853  https://chicago.craigslist.org/chc/cto/d/midlo...
# 151    7303575863  https://worcester.craigslist.org/ctd/d/fitchbu...
# 200    7315267860  https://gainesville.craigslist.org/ctd/d/kissi...
# 251    7316024407  https://reading.craigslist.org/ctd/d/paterson-...
# ...           ...                                                ...
# 9607   7314341390  https://desmoines.craigslist.org/cto/d/urbanda...
# 9659   7304358131  https://vermont.craigslist.org/ctd/d/salem-201...
# 9714   7309686008  https://louisville.craigslist.org/cto/d/radcli...
# 9974   7316447901  https://tulsa.craigslist.org/cto/d/tulsa-2017-...
# 10021  7316458200  https://portland.craigslist.org/mlt/cto/d/port...
#
#                        region                          region_url  price  \
# ...

# %%
# как вариант - брать то слово, которое сразу после названия manufacturer
# попытка - не пытка, как говорится
# создадим новый датафрейм с пропусками
df_with_nan = df[df.model.isna()]
# у нас имеются строчки, где manufacturer указан фигово - убираем их (их всего 2 значения)
# df_with_nan.description.drop('float', axis = 0)
# for i in df_with_nan.description:
# ищем когда значение manufacturer встречается первый раз 
# df_with_nan.drop(df_with_nan[df_with_nan.description == 'float'].index, axis = 0, inplace = True)
# df_with_nan.info()
# df_with_nan = df_with_nan[df_with_nan.manufacturer.dropna()]
df_with_nan.dropna(subset=['manufacturer'], inplace=True)
# теперь, когда убрали пропуски в manufacturer, можно посмотреть какие они значения имеют
for i in df_with_nan.description:
    print(type(i))
# все стринги - это хорошо, теперь попробуем выудить то что нам нужно
for i in df_with_nan.description:
    # идем по описаниям тех машин, где пропущена модель и попробуем брать следующее слово после manufacturer
    # значит в description мы должны найти manufacturer - первое встречающееся
    ind = i.lower().find(
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
# Out:
#  5**5
# 3125
